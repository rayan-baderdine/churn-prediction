# %%
# Cell 1 — Use your module
import sys
sys.path.append('../src')
from preprocessing import load_and_clean, encode_features, get_train_test

df = load_and_clean('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df_encoded = encode_features(df)

print("Shape after encoding:", df_encoded.shape)
print("Class balance:\n", df_encoded['Churn'].value_counts())

# Cell 2 — Check for class imbalance
churn_rate = df_encoded['Churn'].mean()
print(f"Churn rate: {churn_rate:.1%}")
print("Note: ~26% churn — imbalanced. Use AUC-ROC & F1, not accuracy.")

# Cell 3 — Split and save
X_train, X_test, y_train, y_test, scaler = get_train_test(df_encoded)
print("Train size:", X_train.shape)
print("Test size:", X_test.shape)

# Save processed data
import pandas as pd
X_train.to_csv('../data/X_train.csv', index=False)
X_test.to_csv('../data/X_test.csv', index=False)
y_train.to_csv('../data/y_train.csv', index=False)
y_test.to_csv('../data/y_test.csv', index=False)
print("Saved to data/")
# Out:
# Shape after encoding: (7043, 27)
# Class balance:
#  Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64
# Churn rate: 26.5%
# Note: ~26% churn — imbalanced. Use AUC-ROC & F1, not accuracy.
# Train size: (5634, 26)
# Test size: (1409, 26)
# Saved to data/
